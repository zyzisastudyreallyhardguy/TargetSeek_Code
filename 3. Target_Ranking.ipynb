# %% [markdown]
# # Target Ranking
#
# To reproduce the ranking results reported in the paper for the 5 indications, the following code can be used.
#
# It follows the following steps:
#
# 1. Load the disease dataset and the TargetSeek scoring results.
# 2. Train and evaluate the model on the 5 indications
# 3. Obtain the ranking results for the 5 indications
# 4. Calculate the Recall@20, Precision@20, and ROC-AUC for the 5 indications

# %% [markdown]
# ## 1. **Load Disease Dataset and TargetSeek Scoring Results**

# %%
from Target_Ranking_and_Evaluation.utils import *
from Report_Generation_AgentAnalyst.run_section import directory_set_up
import os

# %%
retrieve_path = directory_set_up() + '/Target_Ranking_and_Evaluation'

# %%
os.chdir(retrieve_path)

# %% [markdown]
# load the disease dataset and the TargetSeek scoring results

# %%
disease_path, geneseek_path = get_paths('atherosclerosis')
disease_dataset, geneseek = load_data(disease_path, geneseek_path)

# %%
all_data = process_diseases()
# Out:
# Processing atherosclerosis...
# Processing ibd...
# Processing type2_diabetes...
# Processing rheumatoid_arthritis...
# Processing non_small_cell_lung_cancer...
# Processing metabolic_dysfunction_associated_steatohepatitis_mash...

# %%
all_data = get_T_max(all_data)

# %%
all_data
# Out:
#         CI_Genetic Association  CI_Differential expression  \
# npc1l1                     1.0                         0.5
# p2ry12                     0.5                         1.0
# adrb1                      0.0                        -0.5
# f10                        0.5                        -0.5
# pcsk9                      1.0                         0.5
# ...                        ...                         ...
# eva1a                      0.0                        -0.5
# cobll1                     0.5                        -0.5
# sugp1                      0.0                        -0.5
# macf1                      0.0                        -0.5
# dstyk                      0.0                        -0.5
#
#         CI_Mechanism of Action  CI_In vitro_in vivo experiment  \
# npc1l1                     1.0                             0.5
# p2ry12                     1.0                             1.0
# adrb1                      0.0                             0.5
# f10                        1.0                             0.5
# pcsk9                      1.0                             1.0
# ...                        ...                             ...
# eva1a                     -0.5                             0.5
# cobll1                     0.0                             0.5
# sugp1                      0.5                             0.5
# macf1                      0.5                             0.5
# dstyk                      0.0                             0.5
#
#         T_Small molecules  T_Antibody  T_siRNA  \
# npc1l1                1.0        -0.5      0.5
# p2ry12                1.0         0.0     -1.0
# adrb1                 0.5         0.5      0.5
# f10                   1.0         0.5      0.5
# pcsk9                 1.0         1.0      0.5
# ...                   ...         ...      ...
# eva1a                 0.5         0.5      0.5
# cobll1               -0.5        -1.0      0.5
# sugp1                 0.5        -1.0      0.5
# macf1                 0.5        -0.5      0.5
# dstyk                 0.5        -0.5     -0.5
#
#         CP_Competitiveness_Small_Molecules  \
# npc1l1                                -1.0
# p2ry12                                 0.5
# adrb1                                  1.0
# f10                                    0.5
# pcsk9                                  0.0
# ...                                    ...
# eva1a                                  0.5
# cobll1                                 1.0
# sugp1                                  0.5
# macf1                                  1.0
# dstyk                                  1.0
#
#         CP_Competitiveness_Antibody_or_siRNA  CP_Unmet Needs  \
# npc1l1                                   1.0             0.5
# p2ry12                                   1.0             0.0
# adrb1                                    1.0             1.0
# f10                                      0.0             0.0
# pcsk9                                   -1.0             0.5
# ...                                      ...             ...
# eva1a                                    0.0             1.0
# cobll1                                   0.0             0.0
# sugp1                                    1.0             0.5
# macf1                                    1.0             0.0
# dstyk                                    1.0             1.0
#
#         DO_experimental_model_availability  DO_biomarkers  DO_Safety  NAN  \
# npc1l1                                 1.0            0.0        0.5  NaN
# p2ry12                                 1.0            0.5        0.5  NaN
# adrb1                                  1.0            0.5       -0.5  NaN
# f10                                    1.0            0.5       -0.5  NaN
# pcsk9                                  1.0            1.0        1.0  NaN
# ...                                    ...            ...        ...  ...
# eva1a                                 -1.0           -0.5        0.0  NaN
# cobll1                                 1.0            0.5        0.0  NaN
# sugp1                                  1.0            0.5        0.0  NaN
# macf1                                  0.5            0.5       -0.5  NaN
# dstyk                                  0.5            0.5        0.0  NaN
#
#         DiseaseSpecific_ClinicLabel  \
# npc1l1                          4.0
# p2ry12                          4.0
# adrb1                           4.0
# f10                             4.0
# pcsk9                           4.0
# ...                             ...
# eva1a                           NaN
# cobll1                          NaN
# sugp1                           NaN
# macf1                           NaN
# dstyk                           NaN
#
#                                                   Disease  T_max
# npc1l1                                    atherosclerosis    1.0
# p2ry12                                    atherosclerosis    1.0
# adrb1                                     atherosclerosis    0.5
# f10                                       atherosclerosis    1.0
# pcsk9                                     atherosclerosis    1.0
# ...                                                   ...    ...
# eva1a   metabolic_dysfunction_associated_steatohepatit...    0.5
# cobll1  metabolic_dysfunction_associated_steatohepatit...    0.5
# sugp1   metabolic_dysfunction_associated_steatohepatit...    0.5
# macf1   metabolic_dysfunction_associated_steatohepatit...    0.5
# dstyk   metabolic_dysfunction_associated_steatohepatit...    0.5
#
# [546 rows x 17 columns]

# %% [markdown]
# ## 2. **Training and Evaluation on 5 Indications**

# %% [markdown]
# ##### Model Type Selection: logistic_regression, hist_gradient_boosting, random_forest

# %%
n_iterations = 5

diseases = ['ibd', 'atherosclerosis', 'type2_diabetes', 'rheumatoid_arthritis', 'non_small_cell_lung_cancer']

# model selection
model_type = 'random_forest'

# Dictionary to store results for each disease
results = {disease: [] for disease in diseases}
positive_samples_ranking_dict = {}

for _ in range(n_iterations):
    for test_disease in diseases:
        # Separate the test disease data
        test_data = all_data[all_data['Disease'] == test_disease]
        
        # Combine the other diseases datasets for training
        train_data = all_data[all_data['Disease'] != test_disease]
        
        # Train and evaluate with show_rank=True to display predictions
        accuracy, _, recall, f1, roc_auc, positive_samples_ranked, all_samples_ranked, avg_ranking, feature_importance, recall_at_10, precision_at_10 = train_and_evaluate(train_data, test_data, test_disease, model_type=model_type, show_rank=False, save_ranked_results=False)

        positive_samples_ranking_dict[test_disease] = positive_samples_ranked
        
        # Store results
        results[test_disease].append({
            'roc_auc': roc_auc,
            'avg_ranking': avg_ranking
        })

# Calculate and print average results with standard deviation
for disease in diseases:
    print(f"\nAverage results for {disease} over {n_iterations} iterations:")
    metrics = ['roc_auc', 'avg_ranking']
    for metric in metrics:
        values = [result[metric] for result in results[disease]]
        mean = np.mean(values)
        std = np.std(values)
        print(f"{metric.capitalize()}: {mean:.4f} ± {std:.4f}")
# Out:
# Average results for ibd over 5 iterations:
# Roc_auc: 0.9154 ± 0.0044
# Avg_ranking: 17.0800 ± 0.4045
#
# Average results for atherosclerosis over 5 iterations:
# Roc_auc: 0.8518 ± 0.0056
# Avg_ranking: 20.5800 ± 0.2015
#
# Average results for type2_diabetes over 5 iterations:
# Roc_auc: 0.9453 ± 0.0068
# Avg_ranking: 14.2600 ± 0.3121
#
# Average results for rheumatoid_arthritis over 5 iterations:
# Roc_auc: 0.9571 ± 0.0034
# Avg_ranking: 13.6500 ± 0.2608
#
# Average results for non_small_cell_lung_cancer over 5 iterations:
# Roc_auc: 0.9716 ± 0.0018
# Avg_ranking: 12.3900 ± 0.0735

# %% [markdown]
# ## 3. Obtain Recall@20, Precision@20, and ROC-AUC for each disease

# %%
disease_ranking = {}
for disease in diseases:
    disease_ranking[disease] = ([int(i) for i in positive_samples_ranking_dict[disease]['rank'].tolist()])

    recall_20, _, _ = calculate_recall_precision(disease_ranking[disease])
    print(f"Disease: {disease}")
    print(f"Recall@20: {recall_20:.4f}")
    print("\n" + "="*50)
# Out:
# Disease: ibd
# Recall@20: 0.6000
#
# ==================================================
# Disease: atherosclerosis
# Recall@20: 0.6000
#
# ==================================================
# Disease: type2_diabetes
# Recall@20: 0.8000
#
# ==================================================
# Disease: rheumatoid_arthritis
# Recall@20: 0.7000
#
# ==================================================
# Disease: non_small_cell_lung_cancer
# Recall@20: 0.8000
#
# ==================================================

# %% [markdown]
# ## 4. **Infer Ranking Results for Disease without labels**

# %% [markdown]
# Train a model on all diseases with labels and predict on the disease without labels.
#
# Here, we consider the five indications as the diseases with labels and we use the metabolic_dysfunction_associated_steatohepatitis_mash as the disease without labels.

# %%
# List of training diseases
diseases = ['ibd', 'type2_diabetes', 'rheumatoid_arthritis', 'non_small_cell_lung_cancer', 'atherosclerosis']

# Get MASH data
mash_data = all_data[all_data['Disease'] == 'metabolic_dysfunction_associated_steatohepatitis_mash']

# Train model on all other diseases
train_data = all_data[all_data['Disease'].isin(diseases)]
model, scaler, imputer, feature_columns = train_model_only(train_data, model='random_forest')

# Get predictions for MASH
ranked_mash = predict_new_disease(model, scaler, imputer, feature_columns, mash_data, save_samples=True)

# Display ranked results
print("\nRanked predictions for MASH:")
print(ranked_mash[['predicted_proba', 'rank']].round(4))
# Out:
# Ranked predictions for MASH:
#             predicted_proba  rank
# mtarc1                 0.89   1.0
# pparg                  0.88   2.0
# tm6sf2                 0.75   3.0
# cideb                  0.52   4.0
# mttp                   0.49   5.0
# gpam                   0.46   6.0
# pnpla3                 0.41   7.0
# serpina1               0.30   8.0
# hfe                    0.28   9.0
# rtel1                  0.20  10.0
# abcc2                  0.16  11.0
# dcaf12                 0.15  12.0
# ptpn23                 0.15  12.0
# cd19                   0.14  14.0
# pam                    0.08  15.0
# frat2                  0.08  15.0
# gckr                   0.07  17.0
# npc1                   0.06  18.0
# sugp1                  0.06  18.0
# dnaja3                 0.06  18.0
# ccdc92                 0.06  18.0
# ac022431.2             0.05  22.0
# macf1                  0.05  22.0
# lpl                    0.05  22.0
# vasn                   0.04  25.0
# dnah10                 0.03  26.0
# map3k1                 0.03  26.0
# cobll1                 0.02  28.0
# pik3r3                 0.02  28.0
# dnah10os               0.02  28.0
# eri1                   0.02  28.0
# prmt6                  0.02  28.0
# mlxip                  0.02  28.0
# apoh                   0.02  28.0
# il12rb1                0.02  28.0
# traf3                  0.01  36.0
# l3mbtl3                0.01  36.0
# klc2                   0.01  36.0
# cd248                  0.01  36.0
# cfh                    0.01  36.0
# apoe                   0.01  36.0
# dstyk                  0.01  36.0
# ac007382.1             0.00  43.0
# adam30                 0.00  43.0
# ski                    0.00  43.0
# eva1a                  0.00  43.0

# %%
ranked_mash
# Out:
#             CI_Genetic Association  CI_Differential expression  \
# mtarc1                         0.5                         0.5
# pparg                          0.0                         1.0
# tm6sf2                         1.0                         1.0
# cideb                          1.0                         1.0
# mttp                           0.5                         0.5
# gpam                           1.0                        -0.5
# pnpla3                         1.0                         1.0
# serpina1                       1.0                         0.5
# hfe                            0.5                        -0.5
# rtel1                          0.0                        -0.5
# abcc2                          0.5                        -0.5
# dcaf12                         0.0                        -0.5
# ptpn23                         0.0                        -0.5
# cd19                           0.0                         0.0
# pam                            0.0                        -0.5
# frat2                          0.0                         0.0
# gckr                           0.5                         0.5
# npc1                           1.0                        -0.5
# sugp1                          0.0                        -0.5
# dnaja3                         0.5                         1.0
# ccdc92                         0.0                        -0.5
# ac022431.2                     0.0                         0.0
# macf1                          0.0                        -0.5
# lpl                            0.5                         1.0
# vasn                           0.0                        -0.5
# dnah10                         0.0                         0.5
# map3k1                         0.0                         1.0
# cobll1                         0.5                        -0.5
# pik3r3                         0.0                        -0.5
# dnah10os                       0.0                         0.0
# eri1                           0.0                        -0.5
# prmt6                          0.0                         1.0
# mlxip                          0.0                         1.0
# apoh                           0.0                         1.0
# il12rb1                        0.0                        -0.5
# traf3                          0.0                         1.0
# l3mbtl3                        0.0                        -0.5
# klc2                           0.0                         0.5
# cd248                          0.0                         1.0
# cfh                            0.0                        -0.5
# apoe                           1.0                        -0.5
# dstyk                          0.0                        -0.5
# ac007382.1                     0.0                        -0.5
# adam30                         0.0                        -1.0
# ski                            0.0                        -0.5
# eva1a                          0.0                        -0.5
#
#             CI_Mechanism of Action  CI_In vitro_in vivo experiment  \
# mtarc1                         1.0                             1.0
# pparg                          1.0                             1.0
# tm6sf2                         1.0                             0.5
# cideb                          0.0                             0.5
# mttp                           1.0                             0.5
# gpam                           1.0                             0.5
# pnpla3                         1.0                             0.5
# serpina1                       1.0                             0.5
# hfe                            0.5                             0.5
# rtel1                          0.5                             0.5
# abcc2                          0.5                             0.0
# dcaf12                         0.0                             0.5
# ptpn23                         0.5                             0.5
# cd19                          -0.5                             0.0
# pam                            0.0                             0.5
# frat2                          0.5                             0.0
# gckr                           0.5                             0.5
# npc1                           0.5                             0.5
# sugp1                          0.5                             0.5
# dnaja3                         1.0                             0.5
# ccdc92                         0.5                             0.5
# ac022431.2                     0.5                             0.0
# macf1                          0.5                             0.5
# lpl                            0.5                             0.5
# vasn                           0.5                             0.0
# dnah10                         0.5                             0.0
# map3k1                         0.5                             0.5
# cobll1                         0.0                             0.5
# pik3r3                         0.0                             0.5
# dnah10os                       0.0                             0.0
# eri1                           0.5                             0.5
# prmt6                          0.5                             0.5
# mlxip                          0.0                             0.5
# apoh                           0.0                             0.5
# il12rb1                        0.0                             0.0
# traf3                          0.5                             0.5
# l3mbtl3                       -0.5                             0.0
# klc2                           0.0                             0.0
# cd248                          0.5                             0.5
# cfh                            0.0                             0.5
# apoe                           0.5                             0.5
# dstyk                          0.0                             0.5
# ac007382.1                     0.0                             0.0
# adam30                         0.0                             0.0
# ski                            0.0                             0.0
# eva1a                         -0.5                             0.5
#
#             T_Small molecules  T_Antibody  T_siRNA  \
# mtarc1                    0.0        -1.0      1.0
# pparg                     1.0        -0.5      0.0
# tm6sf2                   -1.0         0.5      1.0
# cideb                     0.0        -1.0      1.0
# mttp                      1.0        -1.0      1.0
# gpam                      0.5        -1.0      1.0
# pnpla3                    0.5         0.0      1.0
# serpina1                 -0.5         0.0      1.0
# hfe                       0.0         0.5      1.0
# rtel1                     0.0        -1.0      0.5
# abcc2                    -0.5         0.0      1.0
# dcaf12                   -0.5        -1.0      0.0
# ptpn23                    0.0         0.0     -1.0
# cd19                      0.0         1.0     -1.0
# pam                       0.5         0.0     -1.0
# frat2                    -0.5        -1.0      0.5
# gckr                      0.5        -1.0      0.5
# npc1                      0.5        -1.0     -0.5
# sugp1                     0.5        -1.0      0.5
# dnaja3                    0.5        -0.5      0.5
# ccdc92                   -1.0         0.5      0.5
# ac022431.2               -1.0        -1.0      0.5
# macf1                     0.5        -0.5      0.5
# lpl                       0.5         0.0      0.5
# vasn                     -0.5         0.0      0.5
# dnah10                   -1.0        -1.0     -0.5
# map3k1                    0.5         0.5      0.5
# cobll1                   -0.5        -1.0      0.5
# pik3r3                   -0.5        -1.0      0.0
# dnah10os                 -1.0        -1.0      0.0
# eri1                     -0.5        -0.5      0.5
# prmt6                     0.5        -0.5      0.5
# mlxip                     0.0        -1.0      0.0
# apoh                     -0.5         0.5      0.5
# il12rb1                   0.5         0.0      0.0
# traf3                    -0.5        -1.0      0.0
# l3mbtl3                   0.5        -1.0      0.0
# klc2                      0.5         0.5      0.0
# cd248                    -1.0         0.5     -0.5
# cfh                      -1.0        -1.0      0.0
# apoe                      0.5        -0.5      0.5
# dstyk                     0.5        -0.5     -0.5
# ac007382.1               -1.0        -1.0     -1.0
# adam30                   -0.5        -1.0      0.0
# ski                      -0.5        -1.0      0.0
# eva1a                     0.5         0.5      0.5
#
#             CP_Competitiveness_Small_Molecules  \
# mtarc1                                     1.0
# pparg                                     -1.0
# tm6sf2                                     0.5
# cideb                                      0.5
# mttp                                       0.0
# gpam                                       1.0
# pnpla3                                     0.5
# serpina1                                   0.5
# hfe                                        0.5
# rtel1                                      1.0
# abcc2                                      1.0
# dcaf12                                     1.0
# ptpn23                                     0.5
# cd19                                       1.0
# pam                                        1.0
# frat2                                      1.0
# gckr                                       0.5
# npc1                                       1.0
# sugp1                                      0.5
# dnaja3                                     0.5
# ccdc92                                     1.0
# ac022431.2                                 1.0
# macf1                                      1.0
# lpl                                        0.5
# vasn                                       1.0
# dnah10                                     1.0
# map3k1                                     1.0
# cobll1                                     1.0
# pik3r3                                     1.0
# dnah10os                                   1.0
# eri1                                       0.5
# prmt6                                      0.5
# mlxip                                      0.5
# apoh                                       0.5
# il12rb1                                    1.0
# traf3                                      0.5
# l3mbtl3                                    0.5
# klc2                                       0.5
# cd248                                      0.5
# cfh                                        1.0
# apoe                                       0.5
# dstyk                                      1.0
# ac007382.1                                 0.5
# adam30                                     1.0
# ski                                        1.0
# eva1a                                      0.5
#
#             CP_Competitiveness_Antibody_or_siRNA  CP_Unmet Needs  \
# mtarc1                                       0.0             1.0
# pparg                                        0.5             0.5
# tm6sf2                                       0.0             0.5
# cideb                                        0.5             1.0
# mttp                                         0.5             0.5
# gpam                                         1.0             1.0
# pnpla3                                       0.0             0.5
# serpina1                                     0.5             0.5
# hfe                                          0.5            -0.5
# rtel1                                        1.0             1.0
# abcc2                                        1.0             0.5
# dcaf12                                       1.0             1.0
# ptpn23                                       0.0             0.0
# cd19                                         1.0            -1.0
# pam                                          1.0             1.0
# frat2                                        1.0             1.0
# gckr                                         1.0             0.0
# npc1                                        -1.0             1.0
# sugp1                                        1.0             0.5
# dnaja3                                       0.0             0.0
# ccdc92                                       0.0             0.5
# ac022431.2                                   1.0             0.0
# macf1                                        1.0             0.0
# lpl                                          1.0             0.0
# vasn                                         1.0             0.5
# dnah10                                       1.0             1.0
# map3k1                                       1.0             0.5
# cobll1                                       0.0             0.0
# pik3r3                                       1.0             0.0
# dnah10os                                     1.0             0.5
# eri1                                         1.0             0.5
# prmt6                                        0.5             0.5
# mlxip                                        1.0             0.0
# apoh                                         0.5             0.0
# il12rb1                                      1.0             0.5
# traf3                                        0.5             1.0
# l3mbtl3                                     -1.0            -0.5
# klc2                                         0.0             0.0
# cd248                                        0.5             1.0
# cfh                                          1.0             1.0
# apoe                                         1.0             0.0
# dstyk                                        1.0             1.0
# ac007382.1                                   1.0             0.0
# adam30                                       1.0             1.0
# ski                                          1.0             1.0
# eva1a                                        0.0             1.0
#
#             DO_experimental_model_availability  DO_biomarkers  DO_Safety  NAN  \
# mtarc1                                     1.0            0.0        0.5  NaN
# pparg                                      1.0           -0.5        0.5  NaN
# tm6sf2                                     1.0            0.5       -0.5  NaN
# cideb                                      1.0            0.5        0.5  NaN
# mttp                                       1.0            0.0       -0.5  NaN
# gpam                                       1.0            0.0        0.5  NaN
# pnpla3                                     1.0            0.0        0.5  NaN
# serpina1                                   0.5            1.0        0.0  NaN
# hfe                                        1.0            0.5       -0.5  NaN
# rtel1                                      1.0            0.5       -0.5  NaN
# abcc2                                      0.5           -0.5       -0.5  NaN
# dcaf12                                     1.0            0.5       -0.5  NaN
# ptpn23                                     1.0            0.0       -1.0  NaN
# cd19                                       0.5            0.0       -1.0  NaN
# pam                                        1.0           -0.5       -0.5  NaN
# frat2                                      1.0           -0.5        0.0  NaN
# gckr                                       1.0            0.5       -0.5  NaN
# npc1                                       1.0            0.0       -0.5  NaN
# sugp1                                      1.0            0.5        0.0  NaN
# dnaja3                                     0.5            0.5       -0.5  NaN
# ccdc92                                     1.0            0.5        0.0  NaN
# ac022431.2                                 1.0            0.5        0.0  NaN
# macf1                                      0.5            0.5       -0.5  NaN
# lpl                                        1.0            0.5        0.5  NaN
# vasn                                       1.0            0.0       -0.5  NaN
# dnah10                                     1.0            0.0        0.0  NaN
# map3k1                                     1.0           -0.5       -0.5  NaN
# cobll1                                     1.0            0.5        0.0  NaN
# pik3r3                                     0.5            0.0        0.5  NaN
# dnah10os                                   1.0            0.5        0.0  NaN
# eri1                                       1.0           -0.5        0.0  NaN
# prmt6                                      1.0            0.0        0.5  NaN
# mlxip                                      1.0           -0.5        0.5  NaN
# apoh                                       1.0            0.5        0.0  NaN
# il12rb1                                    1.0            0.0        0.5  NaN
# traf3                                      0.5            0.0        0.5  NaN
# l3mbtl3                                    0.5            0.5        0.0  NaN
# klc2                                       0.5           -0.5       -0.5  NaN
# cd248                                      0.0            0.0        0.5  NaN
# cfh                                        0.5            1.0        0.0  NaN
# apoe                                       1.0            0.5       -0.5  NaN
# dstyk                                      0.5            0.5        0.0  NaN
# ac007382.1                                -1.0            0.5        0.0  NaN
# adam30                                     1.0            0.5        0.0  NaN
# ski                                        0.5           -0.5        0.0  NaN
# eva1a                                     -1.0           -0.5        0.0  NaN
#
#             DiseaseSpecific_ClinicLabel  \
# mtarc1                              NaN
# pparg                               NaN
# tm6sf2                              NaN
# cideb                               NaN
# mttp                                NaN
# gpam                                NaN
# pnpla3                              NaN
# serpina1                            NaN
# hfe                                 NaN
# rtel1                               NaN
# abcc2                               NaN
# dcaf12                              NaN
# ptpn23                              NaN
# cd19                                NaN
# pam                                 NaN
# frat2                               NaN
# gckr                                NaN
# npc1                                NaN
# sugp1                               NaN
# dnaja3                              NaN
# ccdc92                              NaN
# ac022431.2                          NaN
# macf1                               NaN
# lpl                                 NaN
# vasn                                NaN
# dnah10                              NaN
# map3k1                              NaN
# cobll1                              NaN
# pik3r3                              NaN
# dnah10os                            NaN
# eri1                                NaN
# prmt6                               NaN
# mlxip                               NaN
# apoh                                NaN
# il12rb1                             NaN
# traf3                               NaN
# l3mbtl3                             NaN
# klc2                                NaN
# cd248                               NaN
# cfh                                 NaN
# apoe                                NaN
# dstyk                               NaN
# ac007382.1                          NaN
# adam30                              NaN
# ski                                 NaN
# eva1a                               NaN
#
#                                                       Disease  T_max  \
# mtarc1      metabolic_dysfunction_associated_steatohepatit...    1.0
# pparg       metabolic_dysfunction_associated_steatohepatit...    1.0
# tm6sf2      metabolic_dysfunction_associated_steatohepatit...    1.0
# cideb       metabolic_dysfunction_associated_steatohepatit...    1.0
# mttp        metabolic_dysfunction_associated_steatohepatit...    1.0
# gpam        metabolic_dysfunction_associated_steatohepatit...    1.0
# pnpla3      metabolic_dysfunction_associated_steatohepatit...    1.0
# serpina1    metabolic_dysfunction_associated_steatohepatit...    1.0
# hfe         metabolic_dysfunction_associated_steatohepatit...    1.0
# rtel1       metabolic_dysfunction_associated_steatohepatit...    0.5
# abcc2       metabolic_dysfunction_associated_steatohepatit...    1.0
# dcaf12      metabolic_dysfunction_associated_steatohepatit...    0.0
# ptpn23      metabolic_dysfunction_associated_steatohepatit...    0.0
# cd19        metabolic_dysfunction_associated_steatohepatit...    1.0
# pam         metabolic_dysfunction_associated_steatohepatit...    0.5
# frat2       metabolic_dysfunction_associated_steatohepatit...    0.5
# gckr        metabolic_dysfunction_associated_steatohepatit...    0.5
# npc1        metabolic_dysfunction_associated_steatohepatit...    0.5
# sugp1       metabolic_dysfunction_associated_steatohepatit...    0.5
# dnaja3      metabolic_dysfunction_associated_steatohepatit...    0.5
# ccdc92      metabolic_dysfunction_associated_steatohepatit...    0.5
# ac022431.2  metabolic_dysfunction_associated_steatohepatit...    0.5
# macf1       metabolic_dysfunction_associated_steatohepatit...    0.5
# lpl         metabolic_dysfunction_associated_steatohepatit...    0.5
# vasn        metabolic_dysfunction_associated_steatohepatit...    0.5
# dnah10      metabolic_dysfunction_associated_steatohepatit...   -0.5
# map3k1      metabolic_dysfunction_associated_steatohepatit...    0.5
# cobll1      metabolic_dysfunction_associated_steatohepatit...    0.5
# pik3r3      metabolic_dysfunction_associated_steatohepatit...    0.0
# dnah10os    metabolic_dysfunction_associated_steatohepatit...    0.0
# eri1        metabolic_dysfunction_associated_steatohepatit...    0.5
# prmt6       metabolic_dysfunction_associated_steatohepatit...    0.5
# mlxip       metabolic_dysfunction_associated_steatohepatit...    0.0
# apoh        metabolic_dysfunction_associated_steatohepatit...    0.5
# il12rb1     metabolic_dysfunction_associated_steatohepatit...    0.5
# traf3       metabolic_dysfunction_associated_steatohepatit...    0.0
# l3mbtl3     metabolic_dysfunction_associated_steatohepatit...    0.5
# klc2        metabolic_dysfunction_associated_steatohepatit...    0.5
# cd248       metabolic_dysfunction_associated_steatohepatit...    0.5
# cfh         metabolic_dysfunction_associated_steatohepatit...    0.0
# apoe        metabolic_dysfunction_associated_steatohepatit...    0.5
# dstyk       metabolic_dysfunction_associated_steatohepatit...    0.5
# ac007382.1  metabolic_dysfunction_associated_steatohepatit...   -1.0
# adam30      metabolic_dysfunction_associated_steatohepatit...    0.0
# ski         metabolic_dysfunction_associated_steatohepatit...    0.0
# eva1a       metabolic_dysfunction_associated_steatohepatit...    0.5
#
#             predicted_proba  rank
# mtarc1                 0.89   1.0
# pparg                  0.88   2.0
# tm6sf2                 0.75   3.0
# cideb                  0.52   4.0
# mttp                   0.49   5.0
# gpam                   0.46   6.0
# pnpla3                 0.41   7.0
# serpina1               0.30   8.0
# hfe                    0.28   9.0
# rtel1                  0.20  10.0
# abcc2                  0.16  11.0
# dcaf12                 0.15  12.0
# ptpn23                 0.15  12.0
# cd19                   0.14  14.0
# pam                    0.08  15.0
# frat2                  0.08  15.0
# gckr                   0.07  17.0
# npc1                   0.06  18.0
# sugp1                  0.06  18.0
# dnaja3                 0.06  18.0
# ccdc92                 0.06  18.0
# ac022431.2             0.05  22.0
# macf1                  0.05  22.0
# lpl                    0.05  22.0
# vasn                   0.04  25.0
# dnah10                 0.03  26.0
# map3k1                 0.03  26.0
# cobll1                 0.02  28.0
# pik3r3                 0.02  28.0
# dnah10os               0.02  28.0
# eri1                   0.02  28.0
# prmt6                  0.02  28.0
# mlxip                  0.02  28.0
# apoh                   0.02  28.0
# il12rb1                0.02  28.0
# traf3                  0.01  36.0
# l3mbtl3                0.01  36.0
# klc2                   0.01  36.0
# cd248                  0.01  36.0
# cfh                    0.01  36.0
# apoe                   0.01  36.0
# dstyk                  0.01  36.0
# ac007382.1             0.00  43.0
# adam30                 0.00  43.0
# ski                    0.00  43.0
# eva1a                  0.00  43.0
